# %%
# Import essential libraries for data handling, visualization, and analysis
import pandas as pd

# Import statistical tools
from statsmodels.formula.api import ols
import statsmodels.api as sm

# System and warning configuration
import warnings
import os
warnings.filterwarnings('ignore')  # Suppress all warnings
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %% [markdown]
# ### Load and Prepare Dataset
#
# In this step, we load the raw behavioral dataset from a .parquet file into a DataFrame. We also standardize Sex-related columns (GR_Sex and Sex) by converting all values to lowercase, ensuring consistent formatting for downstream analysis.

# %%
# Define the path to the raw data file (Parquet format)
file_path = "../raw/ambitus_0_15_log_29_07_2025.parquet"
# load the data into a DataFrame
df = pd.read_parquet(file_path)
# Standardize Sex-related columns by converting text to lowercase
df['GR_Sex'] = df['GR_Sex'].str.lower()
df['Sex'] = df['Sex'].str.lower()

# %%
# Drop rows with missing values in Group_Sex or Year
df = df.dropna(subset=['GR_Sex', 'Year'])
# Standardize Group_Sex values to lowercase
df['Sex'] = df['Sex'].str.lower()
# Standardize Group_Sex values to lowercase
df['Group_Sex'] = df['GR_Sex'].str.lower()

# %% [markdown]
# ### Factorial ANOVA – Group × Sex × Year Effects
#
# To evaluate whether behavioral outcomes differ across experimental groups, sexes, and years, we performed a factorial ANOVA on six key behavioral features. The model includes:
# - Main effects: Group, Sex, Year
# - Two-way interactions: Group × Year and Sex × Year
#
# This analysis identifies which behavioral measures show statistically significant differences across subpopulations or temporal contexts. The results are compiled into a unified ANOVA table (final_anova_df) for further inspection and visualization.

# %%
# Drop rows where grouping variables are missing
df = df.dropna(subset=['GR_Sex', 'Year'])
# Normalize Sex information (lowercase for consistency)
df['Sex'] = df['Sex'].str.lower()
df['Group_Sex'] = df['GR_Sex'].str.lower()

# Define variables to test and corresponding feature names in the dataset
anova_targets = {
    'LOCO_TOT': 'Locomotion (Loco_TOT)',
    'LOCO_BEF': 'Locomotion frequency (LOCO_BEF)',
    'EXPL_TOT': 'Exploration (Expl_TOT)',
    'Expl_E_I_BEF_Nr': 'Exploration frequency (Expl_BEF)',
    'L_C': 'Learning capacity (L_C)',
    'E_E': 'Effective exploration ratio (E_E)'
}

# Initialize a list to collect ANOVA results
anova_results = []

# Perform two-way factorial ANOVA for each target variable
# Including main effects and interactions with Year
for feature, description in anova_targets.items():
    formula = f"{feature} ~ C(Group) + C(Sex) + C(Year) + C(Group):C(Year) + C(Sex):C(Year)"
    model = ols(formula, data=df).fit()
    anova_table = sm.stats.anova_lm(model, typ=2)
    # Annotate results with feature description and variable name
    anova_table["Feature"] = description
    anova_table["Variable"] = anova_table.index
    anova_results.append(anova_table.reset_index(drop=True))

# Combine results into a single DataFram
final_anova_df = pd.concat(anova_results, ignore_index=True)

# %%
final_anova_df
# Out:
#           sum_sq      df           F        PR(>F)  \
# 0   1.242915e+04     1.0  147.161912  1.981785e-33
# 1   7.980843e+03     1.0   94.493698  3.747131e-22
# 2   7.104719e+03     6.0   14.020056  6.760442e-16
# 3   6.402366e+03     6.0   12.634071  3.329089e-14
# 4   8.623518e+02     6.0    1.701717  1.163048e-01
# 5   4.516023e+05  5347.0         NaN           NaN
# 6   1.104341e+04     1.0   37.250305  1.112107e-09
# 7   1.314392e+04     1.0   44.335496  3.043736e-11
# 8   3.978023e+04     6.0   22.363657  3.685964e-26
# 9   5.267931e+03     6.0    2.961526  6.898402e-03
# 10  9.517279e+03     6.0    5.350426  1.618466e-05
# 11  1.585198e+06  5347.0         NaN           NaN
# 12  7.171252e+04     1.0  293.815658  3.698463e-64
# 13  1.004687e+03     1.0    4.116335  4.252043e-02
# 14  6.086588e+04     6.0   41.562590  8.552411e-50
# 15  3.210392e+04     6.0   21.922329  1.291152e-25
# 16  5.156980e+03     6.0    3.521471  1.763829e-03
# 17  1.305059e+06  5347.0         NaN           NaN
# 18  8.389022e+03     1.0   67.933850  2.107283e-16
# 19  3.114642e+03     1.0   25.222200  5.275038e-07
# 20  2.526587e+04     6.0   34.100273  1.245522e-40
# 21  9.029473e+03     6.0   12.186698  1.167212e-13
# 22  2.042417e+03     6.0    2.756564  1.121888e-02
# 23  6.602909e+05  5347.0         NaN           NaN
# 24  2.684526e+06     1.0  261.446467  1.878851e-57
# 25  2.875544e+04     1.0    2.800497  9.429357e-02
# 26  1.749583e+06     6.0   28.398700  1.319325e-33
# 27  7.232316e+05     6.0   11.739276  4.085178e-13
# 28  1.269633e+05     6.0    2.060831  5.449543e-02
# 29  5.490286e+07  5347.0         NaN           NaN
# 30  8.015116e+00     1.0  102.575995  6.811654e-24
# 31  2.884809e-01     1.0    3.691926  5.472956e-02
# 32  9.057140e+00     6.0   19.318605  2.094338e-22
# 33  5.889199e+00     6.0   12.561482  4.081113e-14
# 34  1.406327e+00     6.0    2.999653  6.296451e-03
# 35  4.178056e+02  5347.0         NaN           NaN
#
#                               Feature          Variable
# 0               Locomotion (Loco_TOT)          C(Group)
# 1               Locomotion (Loco_TOT)            C(Sex)
# 2               Locomotion (Loco_TOT)           C(Year)
# 3               Locomotion (Loco_TOT)  C(Group):C(Year)
# 4               Locomotion (Loco_TOT)    C(Sex):C(Year)
# 5               Locomotion (Loco_TOT)          Residual
# 6     Locomotion frequency (LOCO_BEF)          C(Group)
# 7     Locomotion frequency (LOCO_BEF)            C(Sex)
# 8     Locomotion frequency (LOCO_BEF)           C(Year)
# 9     Locomotion frequency (LOCO_BEF)  C(Group):C(Year)
# 10    Locomotion frequency (LOCO_BEF)    C(Sex):C(Year)
# 11    Locomotion frequency (LOCO_BEF)          Residual
# 12             Exploration (Expl_TOT)          C(Group)
# 13             Exploration (Expl_TOT)            C(Sex)
# 14             Exploration (Expl_TOT)           C(Year)
# 15             Exploration (Expl_TOT)  C(Group):C(Year)
# 16             Exploration (Expl_TOT)    C(Sex):C(Year)
# 17             Exploration (Expl_TOT)          Residual
# 18   Exploration frequency (Expl_BEF)          C(Group)
# 19   Exploration frequency (Expl_BEF)            C(Sex)
# 20   Exploration frequency (Expl_BEF)           C(Year)
# 21   Exploration frequency (Expl_BEF)  C(Group):C(Year)
# 22   Exploration frequency (Expl_BEF)    C(Sex):C(Year)
# 23   Exploration frequency (Expl_BEF)          Residual
# 24            Learning capacity (L_C)          C(Group)
# 25            Learning capacity (L_C)            C(Sex)
# 26            Learning capacity (L_C)           C(Year)
# 27            Learning capacity (L_C)  C(Group):C(Year)
# 28            Learning capacity (L_C)    C(Sex):C(Year)
# 29            Learning capacity (L_C)          Residual
# 30  Effective exploration ratio (E_E)          C(Group)
# 31  Effective exploration ratio (E_E)            C(Sex)
# 32  Effective exploration ratio (E_E)           C(Year)
# 33  Effective exploration ratio (E_E)  C(Group):C(Year)
# 34  Effective exploration ratio (E_E)    C(Sex):C(Year)
# 35  Effective exploration ratio (E_E)          Residual

# %% [markdown]
# ### ANOVA Summary Table (Formatted for Readability)
#
# The raw factorial ANOVA results are reformatted into a clean summary table. Only the main effects and relevant two-way interactions are retained:
# - Gr: Experimental Group
# - Sex: Biological Sex
# - Year: Testing Year
# - Gr/Y: Group × Year interaction
# - Sex/Y: Sex × Year interaction
#
# Each cell shows the F-statistic along with the associated p-value, helping to quickly identify which variables are significantly influenced by group, sex, year, or their interactions. This format is well-suited for publication or supplementary tables.

# %%
# Create a copy of the original ANOVA results to preserve the source
df_anova = final_anova_df.copy()

# Define a mapping from raw ANOVA variable terms to simplified labels
label_map = {
    'C(Group)': 'Gr',
    'C(Sex)': 'Sex',
    'C(Year)': 'Year',
    'C(Group):C(Year)': 'Gr/Y',
    'C(Sex):C(Year)': 'Sex/Y'
}

# Filter the DataFrame to retain only the terms of interest
df_anova = df_anova[df_anova['Variable'].isin(label_map.keys())]

# Create a new column for simplified effect labels
df_anova['Effect'] = df_anova['Variable'].map(label_map)

# Format the F and p-values into a readable string
df_anova['F(p)'] = df_anova.apply(
    lambda row: f"{row['F']:.2f} (p < {row['PR(>F)']:.4f})", axis=1
)

# Pivot the table so each effect is a column and each feature is a row
table_formatted = df_anova.pivot(index='Feature', columns='Effect', values='F(p)')

# Reorder columns to match desired output
ordered_cols = ['Gr', 'Sex', 'Year', 'Gr/Y', 'Sex/Y']
table_formatted = table_formatted.reindex(columns=ordered_cols)
display(table_formatted)
# Out:
# Effect                                              Gr                 Sex  \
# Feature
# Effective exploration ratio (E_E)  102.58 (p < 0.0000)   3.69 (p < 0.0547)
# Exploration (Expl_TOT)             293.82 (p < 0.0000)   4.12 (p < 0.0425)
# Exploration frequency (Expl_BEF)    67.93 (p < 0.0000)  25.22 (p < 0.0000)
# Learning capacity (L_C)            261.45 (p < 0.0000)   2.80 (p < 0.0943)
# Locomotion (Loco_TOT)              147.16 (p < 0.0000)  94.49 (p < 0.0000)
# Locomotion frequency (LOCO_BEF)     37.25 (p < 0.0000)  44.34 (p < 0.0000)
#
# Effect                                           Year                Gr/Y  \
# Feature
# Effective exploration ratio (E_E)  19.32 (p < 0.0000)  12.56 (p < 0.0000)
# Exploration (Expl_TOT)             41.56 (p < 0.0000)  21.92 (p < 0.0000)
# Exploration frequency (Expl_BEF)   34.10 (p < 0.0000)  12.19 (p < 0.0000)
# Learning capacity (L_C)            28.40 (p < 0.0000)  11.74 (p < 0.0000)
# Locomotion (Loco_TOT)              14.02 (p < 0.0000)  12.63 (p < 0.0000)
# Locomotion frequency (LOCO_BEF)    22.36 (p < 0.0000)   2.96 (p < 0.0069)
#
# Effect                                         Sex/Y
# Feature
# Effective exploration ratio (E_E)  3.00 (p < 0.0063)
# Exploration (Expl_TOT)             3.52 (p < 0.0018)
# Exploration frequency (Expl_BEF)   2.76 (p < 0.0112)
# Learning capacity (L_C)            2.06 (p < 0.0545)
# Locomotion (Loco_TOT)              1.70 (p < 0.1163)
# Locomotion frequency (LOCO_BEF)    5.35 (p < 0.0000)

# %% [markdown]
# ### Experiment with ANOVA Models
#
# -> Playground cell <-
#
# This cell allows you to experiment with different ANOVA models by changing:
# - target_variable: The behavioral feature to analyze (e.g. L_C, EXPL_TOT, E_E, etc.)
# - formula: The structure of the model, including main effects and interactions
#
# Suggestions:
# - Try adding/removing predictors like C(Season) or C(Paradigm)
# - Test interaction terms, e.g. C(Group):C(Sex)
# - Replace the outcome variable with another metric from the dataset
#
# Some combinations may result in collinearity or missing data. Use dropna() as needed:
# df_clean = df.dropna(subset=[target_variable, 'Group', 'Sex', 'Year'])

# %%
# Example: Customize ANOVA feature and formula here

target_variable = 'LOCO_TOT'  # You can change this to any numeric behavioral feature
formula = f"{target_variable} ~ C(Group) + C(Sex) + C(Year) + C(Group):C(Year)"

# Fit the model using ordinary least squares (OLS)
model = ols(formula, data=df).fit()

# Compute the ANOVA table
anova_table = sm.stats.anova_lm(model, typ=2)
display(anova_table)
# Out:
#                          sum_sq      df           F        PR(>F)
# C(Group)           12314.133755     1.0  145.685555  4.080636e-33
# C(Sex)              7980.842955     1.0   94.419434  3.886037e-22
# C(Year)             7104.719036     6.0   14.009037  6.971234e-16
# C(Group):C(Year)    6176.450400     6.0   12.178683  1.193428e-13
# Residual          452464.609990  5353.0         NaN           NaN

# %%
import pingouin as pg

# Válasszuk ki az ICC számításhoz szükséges oszlopokat
df_icc = df[['Animal', 'NR', 'Eff_Expl_EI']].dropna()

# Átnevezés az elvárt formátum szerint
df_icc = df_icc.rename(columns={'Animal': 'subject', 'NR': 'trial', 'Eff_Expl_EI': 'score'})

# ICC számítás (ICC2, kétirányú, abszolút egyezés, több próbára)
icc_result = pg.intraclass_corr(data=df_icc, targets='subject', raters='trial', ratings='score')
icc_result
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 10
#       7 df_icc = df_icc.rename(columns={'Animal': 'subject', 'NR': 'trial', 'Eff_Expl_EI': 'score'})
#       9 # ICC számítás (ICC2, kétirányú, abszolút egyezés, több próbára)
# ---> 10 icc_result = pg.intraclass_corr(data=df_icc, targets='subject', raters='trial', ratings='score')
#      11 icc_result
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pingouin\reliability.py:276, in intraclass_corr(data, targets, raters, ratings, nan_policy)
#     274         data = data.dropna(axis=0, how="any")
#     275     else:
# --> 276         raise ValueError(
#     277             "Either missing values are present in data or "
#     278             "data are unbalanced. Please remove them "
#     279             "manually or use nan_policy='omit'."
#     280         )
#     282 # Back to long-format
#     283 # data_wide = data.copy()  # Optional, for PCA
#     284 data = data.reset_index().melt(id_vars=targets, value_name=ratings)
#
# ValueError: Either missing values are present in data or data are unbalanced. Please remove them manually or use nan_policy='omit'.

# %%
# Csak a szükséges oszlopok
df_icc = df[['Animal', 'NR', 'Eff_Expl_EI']].copy()

# Eldobjuk a NaN értékeket
df_icc = df_icc.dropna()

# Ellenőrizzük, hogy minden állatnál megvan-e mind a 4 próba
valid_animals = df_icc['Animal'].value_counts()
valid_animals = valid_animals[valid_animals == 4].index  # csak akiknek mind a 4 próbája megvan

# Szűrés
df_icc = df_icc[df_icc['Animal'].isin(valid_animals)]

# Átnevezés
df_icc = df_icc.rename(columns={'Animal': 'subject', 'NR': 'trial', 'Eff_Expl_EI': 'score'})

# ICC számítás
icc_result = pg.intraclass_corr(data=df_icc, targets='subject', raters='trial', ratings='score', nan_policy='omit')

# Csak az ICC2 érték
print(icc_result[icc_result['Type'] == 'ICC2'])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[26], line 18
#      15 df_icc = df_icc.rename(columns={'Animal': 'subject', 'NR': 'trial', 'Eff_Expl_EI': 'score'})
#      17 # ICC számítás
# ---> 18 icc_result = pg.intraclass_corr(data=df_icc, targets='subject', raters='trial', ratings='score', nan_policy='omit')
#      20 # Csak az ICC2 érték
#      21 print(icc_result[icc_result['Type'] == 'ICC2'])
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pingouin\reliability.py:302, in intraclass_corr(data, targets, raters, ratings, nan_policy)
#     300     old_options = options.copy()
#     301     options["round"] = None
# --> 302     aov = anova(data=data, dv=ratings, between=[targets, raters], ss_type=2)
#     303     options.update(old_options)  # restore options
#     305 # Extract mean squares
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pingouin\parametric.py:976, in anova(data, dv, between, ss_type, detailed, effsize)
#     972     between = between[0]
#     973 elif len(between) == 2:
#     974     # Two factors with balanced design = Pingouin implementation
#     975     # Two factors with unbalanced design = statsmodels
# --> 976     return anova2(dv=dv, between=between, data=data, ss_type=ss_type, effsize=effsize)
#     977 else:
#     978     # 3 or more factors with (un)-balanced design = statsmodels
#     979     return anovan(dv=dv, between=between, data=data, ss_type=ss_type, effsize=effsize)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pingouin\parametric.py:1063, in anova2(data, dv, between, ss_type, effsize)
#    1061 # Drop missing values
#    1062 data = data[[dv, fac1, fac2]].dropna()
# -> 1063 assert data.shape[0] >= 5, "Data must have at least 5 non-missing values."
#    1065 # Reset index (avoid duplicate axis error)
#    1066 data = data.reset_index(drop=True)
#
# AssertionError: Data must have at least 5 non-missing values.
